# %% [markdown]
# ## Libraries

# %%
import os
import pandas as pd
from time import strftime
from tqdm import tqdm_notebook as tqdm

import glassdoor_metrics

# %% [markdown]
# ## Processing

# %%
company_name = "Novartis Pharmaceuticals"
company_id = 6667

# %%
data = glassdoor_metrics.get_all_company_data(company_id)
#glassdoor_metrics.output_data(data, file_path)

# %%
data
# Out:
# {'Company Info': [{'labels': 'company_name', 'values': 'Novartis'},
#   {'labels': 'company_id', 'values': 6667},
#   {'labels': 'date_scraped', 'values': '2019-02-22'}],
#  'Distr - Category - Biz Outlook': {'labels': ['Getting Better',
#    'Staying the Same',
#    'Getting Worse'],
#   'values': [452, 200, 91]},
#  'Distr - Category - CEO Approval': {'labels': ['Approve', 'Disapprove'],
#   'values': [434, 52]},
#  'Distr - Category - Recommend': {'labels': ['Yes', 'No'],
#   'values': [594, 198]},
#  'Distr - Stars': {'careerOpportunities': [83, 114, 240, 257, 170],
#   'compAndBenefits': [31, 68, 224, 311, 230],
#   'cultureAndValues': [90, 97, 179, 243, 261],
#   'overallRating': [61, 78, 222, 377, 268],
#   'seniorManagement': [130, 146, 233, 234, 122],
#   'stars': ['1 Star', '2 Stars', '3 Stars', '4 Stars', '5 Stars'],
#   'workLife': [81, 97, 197, 265, 234]},
#  'Reviews Breakdown': [{'ceo_reviews_count': '174',
#    'company_reviews_count': '2437',
#    'employees_type': 'REGULAR',
#    'past_employees': 'true'},
#   {'ceo_reviews_count': '10',
#    'company_reviews_count': '171',
#    'employees_type': 'CONTRACT',
#    'past_employees': 'true'},
#   {'ceo_reviews_count': '3',
#    'company_reviews_count': '27',
#    'employees_type': 'PART_TIME',
#    'past_employees': 'true'},
#   {'ceo_reviews_count': '13',
#    'company_reviews_count': '125',
#    'employees_type': 'INTERN',
#    'past_employees': 'true'},
#   {'ceo_reviews_count': '1',
#    'company_reviews_count': '7',
#    'employees_type': 'FREELANCE',
#    'past_employees': 'true'},
#   {'ceo_reviews_count': '114',
#    'company_reviews_count': '1368',
#    'employees_type': 'REGULAR',
#    'past_employees': 'false'},
#   {'ceo_reviews_count': '4',
#    'company_reviews_count': '78',
#    'employees_type': 'CONTRACT',
#    'past_employees': 'false'},
#   {'ceo_reviews_count': '2',
#    'company_reviews_count': '14',
#    'employees_type': 'PART_TIME',
#    'past_employees': 'false'},
#   {'ceo_reviews_count': '5',
#    'company_reviews_count': '36',
#    'employees_type': 'INTERN',
#    'past_employees': 'false'},
#   {'ceo_reviews_count': '1',
#    'company_reviews_count': '3',
#    'employees_type': 'FREELANCE',
#    'past_employees': 'false'}],
#  'Trend - Categories': {'bizOutlook': [0.608378,
#    0.611156,
#    0.638686,
#    0.64005,
#    0.628897,
#    0.62962,
#    0.6035,
#    0.592338,
#    0.596073,
#    0.616596,
#    0.611406,
#    0.607232,
#    0.609274,
#    0.584226,
#    0.586143,
#    0.590686,
#    0.571528,
#    0.563149,
#    0.541038,
#    0.530513,
#    0.512258,
#    0.515436,
#    0.512985,
#    0.516963],
#   'ceoRating': [0.911109,
#    0.918649,
#    0.918275,
#    0.921121,
#    0.938258,
#    0.938063,
#    0.916394,
#    0.933397,
#    0.967594,
#    1.0,
#    1.0,
#    0.849257,
#    0.868077,
#    0.87772,
#    0.881771,
#    0.894557,
#    0.884366,
#    0.877163,
#    0.857217,
#    0.855122,
#    0.838575,
#    0.847357,
#    0.852085,
#    0.864923],
#   'date': ['2019/2/17',
#    '2019/1/27',
#    '2018/12/30',
#    '2018/11/25',
#    '2018/10/28',
#    '2018/9/30',
#    '2018/8/26',
#    '2018/7/29',
#    '2018/6/24',
#    '2018/5/27',
#    '2018/4/29',
